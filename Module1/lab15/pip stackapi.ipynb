# %%
pip install stackapi
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from stackapi import StackAPI

# %%
website= StackAPI ('stackoverflow')
questions = website.fetch('questions',fromdate='2022-07-01', todate='2022-07-31')

# %%
question_list=[question['title'] for question in questions ['items']]

# %%
print(question_list)
# Out:
# ['Redirect from non-www to www with Traefik 2', 'Which is better answer about security?', 'Detect intersection between two svg shape', 'telegram bot that can handle multiple users at the same time - python', 'how to find all devices connected to wifi network with scapy and python for windows and android', 'Rename a column with R', 'Vercel - on Pull Request merge to master build promotes to production with preview env variables', 'How to cluster questionnaire items together to create 1 variable? When I run multivariate linear model no output is given? what analyses should i use?', 'Which of the three research directions of AI+WEB security, AI model security, and malicious traffic detection is recommended?', 'Process calculation of SAPID on basis of bill start date and bill ENd date in oracle procedure', 'Jenkins fails to execute app:processDebugResources with AarResourcesCompilerTransform error', 'Facing issue in GITLAB while reconfiguring', 'Issue with getOoxml() and insertOoxml() fo
# ...

# %%
question_id=[question['question_id']for question in questions ['items']]

# %%
print (question_id)
# Out:
# [73112737, 73092419, 73113807, 72905772, 72971193, 73008532, 73072610, 73143587, 73146631, 73152528, 73174781, 72965409, 72955303, 73038326, 72861817, 73097848, 73179098, 73008359, 72936183, 73149716, 72863441, 73177960, 73125516, 73172919, 73118558, 73036082, 73053973, 73135855, 72901771, 73148832, 73173340, 72882381, 73177347, 73006023, 73068818, 73060287, 73154477, 72980735, 73143026, 73064859, 73158839, 73003127, 73074407, 73098125, 73001238, 73161518, 73061074, 73023097, 73085488, 73117484, 73150123, 72867845, 73062460, 73133687, 73061520, 73150935, 73095392, 73073641, 73177982, 73156192, 72869370, 73156243, 73098271, 73120053, 72987147, 73047247, 73138299, 73135422, 73111938, 73002665, 73144536, 73075434, 73170496, 73173157, 73172556, 72824450, 73111496, 72893577, 73116391, 72893373, 72964221, 73111031, 73103201, 72908270, 73176698, 73179426, 73166802, 73158539, 72944366, 72863892, 72883543, 73168573, 73131586, 73086380, 73179104, 73167935, 72894373, 73064328, 73036841, 7289685
# ...

# %%
questions= website.fetch('questions', fromdate="2022-07-01", todate="2022-07-31")

# %%
print (questions)
# Out:
# {'backoff': 0, 'has_more': True, 'page': 5, 'quota_max': 300, 'quota_remaining': 290, 'total': 0, 'items': [{'tags': ['docker-compose', 'traefik'], 'owner': {'reputation': 133, 'user_id': 15163517, 'user_type': 'registered', 'profile_image': 'https://lh3.googleusercontent.com/a-/AOh14GiuYD9wfqM05sXL1L6UABf-8WkojXoStO2fbs0o=k-s256', 'display_name': 'Federico Galimberti', 'link': 'https://stackoverflow.com/users/15163517/federico-galimberti'}, 'is_answered': True, 'view_count': 57, 'answer_count': 1, 'score': 0, 'last_activity_date': 1659902652, 'creation_date': 1658767698, 'last_edit_date': 1659902652, 'question_id': 73112737, 'content_license': 'CC BY-SA 4.0', 'link': 'https://stackoverflow.com/questions/73112737/redirect-from-non-www-to-www-with-traefik-2', 'title': 'Redirect from non-www to www with Traefik 2'}, {'tags': ['java', 'security', 'visibility'], 'owner': {'reputation': 1, 'user_id': 5251324, 'user_type': 'registered', 'profile_image': 'https://www.gravatar.com/avatar/5eb
# ...

# %%
from stackapi import StackAPI
answers = SITE.fetch('answers', ids=[6784, 6473])
answers
# Out:
# {'backoff': 0,
#  'has_more': False,
#  'page': 1,
#  'quota_max': 300,
#  'quota_remaining': 295,
#  'total': 0,
#  'items': [{'owner': {'reputation': 30383,
#     'user_id': 758,
#     'user_type': 'registered',
#     'accept_rate': 77,
#     'profile_image': 'https://www.gravatar.com/avatar/0b4adc19284ed0751844d610555dc6b2?s=256&d=identicon&r=PG',
#     'display_name': 'Mark Renouf',
#     'link': 'https://stackoverflow.com/users/758/mark-renouf'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1218291583,
#    'creation_date': 1218291583,
#    'answer_id': 6784,
#    'question_id': 6778,
#    'content_license': 'CC BY-SA 2.5'}]}
