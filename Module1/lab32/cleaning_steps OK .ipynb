# %%
import pandas as pd
data=pd.read_excel(r'/Users/naitsaidifariza/Downloads/example_data_cleaning.xlsx')
import matplotlib.pyplot as plt

# %%
data = data.drop_duplicates(keep='first')
data
# Out:
#     TransactionID  ClientID    BirthYear     Amount   Profession  Department  \
# 0             1.0   34982.0  2013.000000    12900.0      Student        78.0
# 1             2.0   34983.0  2015.000000     1230.0       barmen        78.0
# 2             3.0   34984.0  1945.000000     3450.0      student        78.0
# 3             4.0   34985.0  1923.000000     5670.0      manager        78.0
# 4             5.0   34986.0  1978.000000     7890.0           hr        78.0
# 5             6.0   34987.0  1967.000000    10110.0      Manager        78.0
# 6            15.0   34987.0  1967.000000    30090.0      Manager        78.0
# 7            22.0   34987.0          NaN    18990.0       sailer        78.0
# 8             7.0   34988.0          NaN    12330.0      Manager        78.0
# 9            23.0   34988.0  1999.000000    25650.0      Manager        78.0
# 10            8.0   34989.0  1958.000000    14550.0           HR        78.0
# ...

# %%
data=data.dropna(subset=['TransactionID'])
data
# Out:
#     TransactionID  ClientID    BirthYear     Amount   Profession  Department  \
# 0             1.0   34982.0  2013.000000    12900.0      Student        78.0
# 1             2.0   34983.0  2015.000000     1230.0       barmen        78.0
# 2             3.0   34984.0  1945.000000     3450.0      student        78.0
# 3             4.0   34985.0  1923.000000     5670.0      manager        78.0
# 4             5.0   34986.0  1978.000000     7890.0           hr        78.0
# 5             6.0   34987.0  1967.000000    10110.0      Manager        78.0
# 6            15.0   34987.0  1967.000000    30090.0      Manager        78.0
# 7            22.0   34987.0          NaN    18990.0       sailer        78.0
# 8             7.0   34988.0          NaN    12330.0      Manager        78.0
# 9            23.0   34988.0  1999.000000    25650.0      Manager        78.0
# 10            8.0   34989.0  1958.000000    14550.0           HR        78.0
# ...

# %%
data=data.dropna(subset=['ClientID'])
data
# Out:
#     TransactionID  ClientID    BirthYear     Amount   Profession  Department  \
# 0             1.0   34982.0  2013.000000    12900.0      Student        78.0
# 1             2.0   34983.0  2015.000000     1230.0       barmen        78.0
# 2             3.0   34984.0  1945.000000     3450.0      student        78.0
# 3             4.0   34985.0  1923.000000     5670.0      manager        78.0
# 4             5.0   34986.0  1978.000000     7890.0           hr        78.0
# 5             6.0   34987.0  1967.000000    10110.0      Manager        78.0
# 6            15.0   34987.0  1967.000000    30090.0      Manager        78.0
# 7            22.0   34987.0          NaN    18990.0       sailer        78.0
# 8             7.0   34988.0          NaN    12330.0      Manager        78.0
# 9            23.0   34988.0  1999.000000    25650.0      Manager        78.0
# 10            8.0   34989.0  1958.000000    14550.0           HR        78.0
# ...

# %%
data
#TransactionID:check for duplicates in the TransactionID column, drop duplicates if present: data = data.drop_duplicates(keep='first')
#drop row if nan : data=data.dropna(subset=['TransactionID'])

#ClientID: check for missing client ids, drop row: data=data.dropna(subset=['ClientID'])

#BirthYear: check for outlier birth years and drop those rows : less than 18 or greater than 100; 
#data=data[(data['BirthYear]> 2004') & (data['BirthYear']<1922')])]
#check for missing values: replace them with a mean: data['BirthYear'].fillna(value=data['BirthYear'].mean(),inplace=True)

#Amount: check for outliers: plot a scatter graph:data.plot.scatter(x = 'ClientID', y = 'Amount').Based on the plot, drop any value greater than 1x10^6
#by : data=data[data['Amount']<1^10^6]

#Profession: replace nan with not disclosed: data.loc[data['Profession'].isna() == True,data['Profession']]='Not disclosed'
#replace all values with a lower case value: data['Profession']=data['Profession'].str.lower()
#data.loc[data['Profession']== 'etudient',data['Profession']]='student'
#data.loc[data['Profession']== 'barmen',data['Profession']]='barman'

#Department: check for missing values and replace them with the mode  drop data['Department']         

#Risk: df['Department'].fillna(('High', inplace=True)
data
# Out:
#     TransactionID  ClientID    BirthYear     Amount   Profession  Department  \
# 0             1.0   34982.0  2013.000000    12900.0      Student        78.0
# 1             2.0   34983.0  2015.000000     1230.0       barmen        78.0
# 2             3.0   34984.0  1945.000000     3450.0      student        78.0
# 3             4.0   34985.0  1923.000000     5670.0      manager        78.0
# 4             5.0   34986.0  1978.000000     7890.0           hr        78.0
# 5             6.0   34987.0  1967.000000    10110.0      Manager        78.0
# 6            15.0   34987.0  1967.000000    30090.0      Manager        78.0
# 7            22.0   34987.0          NaN    18990.0       sailer        78.0
# 8             7.0   34988.0          NaN    12330.0      Manager        78.0
# 9            23.0   34988.0  1999.000000    25650.0      Manager        78.0
# 10            8.0   34989.0  1958.000000    14550.0           HR        78.0
# ...

# %%
data=data[(data['BirthYear']< 2004)& (data['BirthYear']>1922)]
data
# Out:
#     TransactionID  ClientID    BirthYear     Amount   Profession  Department  \
# 2             3.0   34984.0  1945.000000     3450.0      student        78.0
# 3             4.0   34985.0  1923.000000     5670.0      manager        78.0
# 4             5.0   34986.0  1978.000000     7890.0           hr        78.0
# 5             6.0   34987.0  1967.000000    10110.0      Manager        78.0
# 6            15.0   34987.0  1967.000000    30090.0      Manager        78.0
# 9            23.0   34988.0  1999.000000    25650.0      Manager        78.0
# 10            8.0   34989.0  1958.000000    14550.0           HR        78.0
# 11           24.0   34989.0  1967.000000    27870.0           HR        78.0
# 12            9.0   34990.0  1953.285714    16770.0      Manager        78.0
# 13           10.0   34991.0  1988.000000    18990.0          BDM        78.0
# 14           30.0   34991.0  1988.000000    55250.0          BDM        78.0
# ...

# %%
data['BirthYear'].fillna(value=data['BirthYear'].mean(),inplace=True)
data
# Out:
#     TransactionID  ClientID    BirthYear     Amount   Profession  Department  \
# 0             1.0   34982.0  2013.000000    12900.0      Student        78.0
# 1             2.0   34983.0  2015.000000     1230.0       barmen        78.0
# 2             3.0   34984.0  1945.000000     3450.0      student        78.0
# 3             4.0   34985.0  1923.000000     5670.0      manager        78.0
# 4             5.0   34986.0  1978.000000     7890.0           hr        78.0
# 5             6.0   34987.0  1967.000000    10110.0      Manager        78.0
# 6            15.0   34987.0  1967.000000    30090.0      Manager        78.0
# 7            22.0   34987.0  1968.316327    18990.0       sailer        78.0
# 8             7.0   34988.0  1968.316327    12330.0      Manager        78.0
# 9            23.0   34988.0  1999.000000    25650.0      Manager        78.0
# 10            8.0   34989.0  1958.000000    14550.0           HR        78.0
# ...

# %%
data.plot.scatter(x = 'ClientID', y = 'Amount')
data
# Out:
#     TransactionID  ClientID    BirthYear     Amount   Profession  Department  \
# 2             3.0   34984.0  1945.000000     3450.0      student        78.0
# 3             4.0   34985.0  1923.000000     5670.0      manager        78.0
# 4             5.0   34986.0  1978.000000     7890.0           hr        78.0
# 5             6.0   34987.0  1967.000000    10110.0      Manager        78.0
# 6            15.0   34987.0  1967.000000    30090.0      Manager        78.0
# 9            23.0   34988.0  1999.000000    25650.0      Manager        78.0
# 10            8.0   34989.0  1958.000000    14550.0           HR        78.0
# 11           24.0   34989.0  1967.000000    27870.0           HR        78.0
# 12            9.0   34990.0  1953.285714    16770.0      Manager        78.0
# 13           10.0   34991.0  1988.000000    18990.0          BDM        78.0
# 14           30.0   34991.0  1988.000000    55250.0          BDM        78.0
# ...

# %%
data=data[data['Amount']<1000000]
data
# Out:
#     TransactionID  ClientID    BirthYear   Amount   Profession  Department  \
# 2             3.0   34984.0  1945.000000   3450.0      student        78.0
# 3             4.0   34985.0  1923.000000   5670.0      manager        78.0
# 4             5.0   34986.0  1978.000000   7890.0           hr        78.0
# 5             6.0   34987.0  1967.000000  10110.0      Manager        78.0
# 6            15.0   34987.0  1967.000000  30090.0      Manager        78.0
# 9            23.0   34988.0  1999.000000  25650.0      Manager        78.0
# 10            8.0   34989.0  1958.000000  14550.0           HR        78.0
# 11           24.0   34989.0  1967.000000  27870.0           HR        78.0
# 12            9.0   34990.0  1953.285714  16770.0      Manager        78.0
# 13           10.0   34991.0  1988.000000  18990.0          BDM        78.0
# 14           30.0   34991.0  1988.000000  55250.0          BDM        78.0
# ...

# %%
data.loc[data['Profession'].isna() == True,'Profession']='Not disclosed'
data
# Out:
#     TransactionID  ClientID    BirthYear   Amount     Profession  Department  \
# 2             3.0   34984.0  1945.000000   3450.0        student        78.0
# 3             4.0   34985.0  1923.000000   5670.0        manager        78.0
# 4             5.0   34986.0  1978.000000   7890.0             hr        78.0
# 5             6.0   34987.0  1967.000000  10110.0        Manager        78.0
# 6            15.0   34987.0  1967.000000  30090.0        Manager        78.0
# 9            23.0   34988.0  1999.000000  25650.0        Manager        78.0
# 10            8.0   34989.0  1958.000000  14550.0             HR        78.0
# 11           24.0   34989.0  1967.000000  27870.0             HR        78.0
# 12            9.0   34990.0  1953.285714  16770.0        Manager        78.0
# 13           10.0   34991.0  1988.000000  18990.0            BDM        78.0
# 14           30.0   34991.0  1988.000000  55250.0            BDM        78.0
# ...

# %%
df_dummies = data
pd.get_dummies(df_dummies)
# Out:
#     TransactionID  ClientID    BirthYear   Amount  Department  Profession_BDM  \
# 2             3.0   34984.0  1945.000000   3450.0        78.0               0
# 3             4.0   34985.0  1923.000000   5670.0        78.0               0
# 4             5.0   34986.0  1978.000000   7890.0        78.0               0
# 5             6.0   34987.0  1967.000000  10110.0        78.0               0
# 6            15.0   34987.0  1967.000000  30090.0        78.0               0
# 9            23.0   34988.0  1999.000000  25650.0        78.0               0
# 10            8.0   34989.0  1958.000000  14550.0        78.0               0
# 11           24.0   34989.0  1967.000000  27870.0        78.0               0
# 12            9.0   34990.0  1953.285714  16770.0        78.0               0
# 13           10.0   34991.0  1988.000000  18990.0        78.0               1
# 14           30.0   34991.0  1988.000000  55250.0        78.0               1
# ...
