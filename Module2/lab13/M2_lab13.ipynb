# %% [markdown]
# # Before your start:
# - Read the README.md file.
# - Comment as much as you can and use the resources (README.md file).
# - Happy learning!

# %%
# Libraries

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy.stats as stats

# %% [markdown]
# # Challenge 1 - Generate and Plot Normal Distributions
# #### Step 1: Generate samples and test normal distribution.
#
# Use mean=50, standard_deviation=5, and sample_size=[10, 50, 500, 5000] to generate 4 random samples that are normally distributed.
#
# **Hint**: Read the documentation for `scipy.stats.norm.rvs`. The function will help you create the normal random samples.

# %%
# your code here
from scipy.stats import norm
mean=50
standard_deviation=5
sample_size=[10, 50, 500, 5000]
samples=[]
for i in sample_size:
    r = norm.rvs(loc=mean, scale=standard_deviation, size=i)
    samples.append(r)
print('Sample 1: ', samples[0])
print('Sample 2: ', samples[1])
print('Sample 3: ', samples[2])
print('Sample 4: ', samples[3])
# Out:
# Sample 1:  [44.96716579 56.40133536 59.32369252 56.19849504 42.00696668 48.61716375
#  51.20753712 51.66942862 50.01109351 55.08414926]
# Sample 2:  [51.86037405 42.82289707 40.34780535 48.48592721 46.85879939 54.94171763
#  55.72216409 49.52759859 54.9520681  52.79975371 57.11797319 36.34472757
#  48.54137963 51.99805993 48.88129393 51.46277547 50.76270795 51.73972177
#  55.19406731 52.10751273 53.24318213 57.860991   51.72399808 55.36570683
#  55.73905398 52.36265481 46.89765803 50.6184596  53.8008543  44.18017757
#  42.64782007 50.13907997 45.98606912 47.90402289 53.72645746 40.95588892
#  47.90173327 52.85072908 55.02999171 48.85473389 42.56740211 42.56462939
#  49.18479696 51.64809698 47.52154912 47.39300923 55.70548761 43.46810093
#  47.14109838 50.93625599]
# Sample 3:  [48.90495144 43.65641418 46.17158728 46.58362864 51.97798698 50.57306625
#  52.88342994 45.71343153 50.65411434 46.40254986 44.69718271 47.77278076
#  54.1616479  44.36004374 50.47200491 50.76156443 45.48453367 57.13877095
#  57.23019253 53.20896423 38.58711312 47.20314828 56.63907194 44.96568176
#  53.58089862 48.95234878 47.83609632 49.09615469 45.79612564 51.03660004
#  51.20816582 46.50204548 46.25579591 46.2547524  43.27814556 56.08601665
#  50.49033309 59.76586446 50.82899369 38.17608506 44.30023332 47.85568716
#  54.28112607 50.15430949 49.60466644 49.25045696 52.63470234 48.13316065
#  50.69352714 55.08532346 50.33244494 54.12297402 50.87255144 47.30906981
#  50.88246329 45.98860157 45.6813601  52.85652454 48.9707826  46.34607077
#  45.5770049  50.93973814 52.60532023 44.00344036 53.40611454 46.25329498
#  50.96742013 50.89915701 60.10420136 45.28347404 52.02378903 46.77244665
#  54.12457862 51.30114054 53.91472711 50.89618216 54.25980929 54.96631023
#  44.58232733 51.76438046 53.73353773 54.5041744  53.61012962 51.30600763
#  42.18751074 47.38334776 48.54247041 49.08142215 52.2980823  44.32830732
#  51.69953281 46.71106032 51.48703397 48.91663474 48.913307   41.20069523
#  44.81598075 46.33873715 43.69546052 45.52038919 50.62996351 42.34626139
#  53.64332287 42.4632381  48.32066966 50.5897018  50.45966322 52.44567854
#  53.81756847 47.38823301 52.15795281 37.91755886 51.43061952 58.71608963
#  52.45312385 37.64050842 47.60950058 51.41234396 52.7523443  49.99522066
#  52.7487557  49.24178582 54.65678217 42.65170467 49.32119282 51.0172602
#  44.37665634 47.80441999 38.14967711 54.75109209 49.74269244 57.58078731
#  50.88512924 55.36813711 44.95261682 51.31587434 43.64567458 49.32501732
#  48.12741997 56.25724428 52.54666365 55.78251614 43.11935462 44.09159386
#  51.38921072 49.40813108 56.8464043  49.77915698 49.71707848 43.90736197
#  49.44235888 49.63199794 50.21335546 43.14668009 46.43509827 46.66953289
#  51.3079491  52.48204513 52.97490132 49.01835023 49.99372569 53.4601266
#  55.66650346 56.20080895 49.78099739 50.20840442 49.37146078 51.04701869
#  54.6442394  48.33677603 48.80330654 51.11706973 45.96982219 55.12075622
#  54.52457752 42.97255932 56.04234647 51.17066302 46.30436768 49.23244664
#  51.95863357 48.6891486  45.94819762 55.14759387 48.61337688 50.40180819
#  53.68485487 42.95452344 56.67207821 50.91277559 57.40458364 53.19252143
#  51.98298155 56.75042784 52.59647112 45.48812525 46.80951359 52.20137679
#  48.84213086 51.77588092 48.8372272  47.30530852 45.61915121 48.39938298
#  48.43223867 51.47653874 52.33345225 37.57484791 48.80154101 44.37523956
#  50.85831976 42.24402502 49.36875567 44.5688913  46.03020015 52.7256426
#  51.87430219 45.10237943 46.39354827 48.50166537 46.76552402 57.96218967
#  55.26254337 49.97971961 51.52648676 47.28686486 53.99516523 46.30772431
#  57.15831267 47.31891032 46.15284034 44.24733077 45.93782574 49.51231969
#  51.7741931  52.79213351 43.70233239 44.26465511 48.13746424 50.37355842
#  47.86336088 52.02797323 55.84944391 57.42639263 57.15422729 52.55345396
#  49.0140383  57.3973903  46.4942767  40.1305956  51.24354222 48.45611257
#  50.25212327 43.80333948 47.87270528 55.54884399 51.45165462 48.34776272
#  41.60133061 44.03137679 45.4988933  54.58829008 49.46814262 53.23120349
#  57.34211683 44.82116796 50.94419303 53.77902082 55.02604524 53.49990868
#  50.20564815 60.10596635]
# Sample 4:  [59.05794983 44.83090471 48.26694983 ... 49.19612772 52.49056054
#  46.02337675]

# %%
print('Sample 1: ', len(samples[0]))
print('Sample 2: ', len(samples[1]))
print('Sample 3: ', len(samples[2]))
print('Sample 4: ', len(samples[3]))
# Out:
# Sample 1:  10
# Sample 2:  50
# Sample 3:  500
# Sample 4:  5000

# %%
from scipy.stats import norm
mean=50
standard_deviation=5
sample_size=[10, 50, 500, 5000]
for i in sample_size:
    population=pd.DataFrame(np.random.normal(mean, standard_deviation, size=i))
    population.mean()
    population.hist()
    plt.show()

# %% [markdown]
# #### Step 2: Plot normal distributions.
#
# To check the shape of the samples you have just created, you can use matplotlib. For example, you can use it to plot a histogram of each sample.
#
# If you did, your outputs would be really similar to the ones below:
#
# ![normal distributions with different sample sizes](../images/ch-1.png)

# %% [markdown]
# #### Compare the distributions above. What do you observe? Explain with the Central Limit Theorem.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.hist(samples[0], bins=10)
plt.gca().set(title='Sample 1 distribution Histogram', ylabel='Frequency');

# %%
plt.hist(samples[1], bins=10)
plt.gca().set(title='Sample 2 distribution Histogram', ylabel='Frequency');

# %%
plt.hist(samples[2], bins=10)
plt.gca().set(title='Sample 3 distribution Histogram', ylabel='Frequency');

# %%
plt.hist(samples[3], bins=10)
plt.gca().set(title='Sample 4 distribution Histogram', ylabel='Frequency');

# %% [markdown]
# #### Bonus: Plot normal distributions.
#
# Even though you still don't know how to use matplotlib, as a bonus challenge, you can try to reproduce the plot above using the samples you have created. This plotting library will be introduced later this week, so don't worry if you don't manage to get the results you want now: you can always come back to solve this challenge later.

# %%
# your code here

# %% [markdown]
# # Challenge 2 - Plot Probability Mass Function (PMF)

# %% [markdown]
# ### Background knowledge
#
# [PMF](https://en.wikipedia.org/wiki/Probability_mass_function) shows the probability distribution of a **discrete random variable**. A [discrete random variable](https://en.wikipedia.org/wiki/Random_variable#Discrete_random_variable) has random numeric values that are not continuous. For example, the number of people in a household can only be integers but not floats. Therefore the number of people in a household is a discrete variable.
#
# ### Challenge
#
# We assume that the probability of clicking an advertisement in a Youtube video is 0.15. We have a sample of 5 people who watched the video and we want to plot the PMF for a binomial distribution.
#
# #### Step 1: Create the binomial distribution mentioned above. Store the result in a variable called `dist`.
# **Hint**: use binom from `scipy.stats.binom`. This object takes *n* and *p* as shape parameters, where *n* is the number of independent experiments and *p* the probability of success of the experiment.

# %%
# your code here
from scipy.stats import binom
# proba of cliking
p=0.15 
# sample size
n=5
#nb of watch per person
k=1
dist=binom(n, p)
dist

# %% [markdown]
# #### Step 2: Plot the PMF of the distribution.
# To do it, run the code in the cell below.
#
# **Hint**: Your output should look like the one below:
#
# ![binom 10](../images/ch-2.png)

# %%
# run this code
x = range(n)

fig, ax = plt.subplots(1, 1)

plt.plot(x, dist.pmf(x))

plt.show()

# %% [markdown]
# #### Step 3: Explain what you observe from the plot above.

# %%
"""
your comments here
"""

# %% [markdown]
# #### Step 4: Now plot PMF with 50, 500, and 5000 visitors.
# To plot the PMF, you can copy the code given above and replace variable `dist` for the name of the variables where you have stored the new binomial objects for 50, 500 and 5000 visitors.

# %%
# your code here
n=50
dist_50=binom(n, p)
dist_50

x = range(n)
fig, ax = plt.subplots(1, 1)
plt.plot(x, dist_50.pmf(x))
plt.show()

# %%
n=500
dist_500=binom(n, p)
dist_500

x = range(n)
fig, ax = plt.subplots(1, 1)
plt.plot(x, dist_500.pmf(x))
plt.show()

# %%
n=5000
dist_5000=binom(n, p)
dist_5000

x = range(n)
fig, ax = plt.subplots(1, 1)
plt.plot(x, dist_5000.pmf(x))
plt.show()
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/scipy/stats/_discrete_distns.py:67: RuntimeWarning: divide by zero encountered in _binom_pdf
#   return _boost._binom_pdf(x, n, p)

# %% [markdown]
# #### Step 5: What did you notice from the distribution plots? Comment your findings.

# %%
"""
your comments here
"""

# %% [markdown]
# # Challenge 3
# #### Step 1: Research the Poisson distribution. Write about your own understanding of the Poisson distribution.

# %%
"""
your comments here
"""

# %% [markdown]
# #### Step 2: A website has an average of 300 visits per day. What is the probability of getting 320 visitors in a day?
#
# **Hint**: use `scipy.stats.poisson.pmf`.

# %%
# your code here
from scipy.stats import poisson
poisson.pmf(320,300)
# Out:
# 0.011612348610402475

# %% [markdown]
# #### Step 3: What is the probability of getting 60 visits?

# %%
# your code here
poisson.pmf(60,300)
# Out:
# 2.622743762294515e-64

# %% [markdown]
# #### Step 4: Create a list to store the Poisson distribution probabilities for 0 to 1000 visitors. Store your list in a variable called `arr`.

# %%
# your code here
arr=[]
for i in range(1000):
    arr.append(poisson.pmf(i,mu=300))
print(arr)
# Out:
# [5.148200222412013e-131, 1.5444600667235709e-128, 2.3166901000854342e-126, 2.31669010008539e-124, 1.7375175750640974e-122, 1.042510545038448e-120, 5.212552725192131e-119, 2.23395116793948e-117, 8.377316879773299e-116, 2.7924389599243865e-114, 8.377316879773059e-113, 2.2847227853926804e-111, 5.71180696348157e-110, 1.318109299264997e-108, 2.824519926996411e-107, 5.649039853992778e-106, 1.0591949726236754e-104, 1.8691675987476173e-103, 3.1152793312460596e-102, 4.918862101967454e-101, 7.378293152951289e-100, 1.0540418789930416e-98, 1.4373298349904852e-97, 1.874778045639763e-96, 2.3434725570497126e-95, 2.812167068459659e-94, 3.2448081559150323e-93, 3.605342395461095e-92, 3.8628668522797225e-91, 3.996069157530829e-90, 3.9960691575307916e-89, 3.8671637008362115e-88, 3.6254659695339394e-87, 3.295878154121811e-86, 2.908127783048746e-85, 2.492680956898807e-84, 2.0772341307490223e-83, 1.684243889796562e-82, 1.3296662287866792e-81, 1.0228201759897706e-80, 7.671151319923377e-80, 5.61303755116352e-79, 4.009312536545479e-78, 2.7971947929385084e-77, 1.9071782679126897e-76, 1.2714521786084167e-75, 8.292079425707285e-75, 5.292816654706792e-74, 3.308010409191751e-73, 2.0253124954234986e-72, 1.2151874972541331e-71, 7.1481617485533646e-71, 4.123939470319411e-70, 2.334305360558085e-69, 1.2968363114211372e-68, 7.073652607751824e-68, 3.789456754152734e-67, 1.9944509232382822e-66, 1.0316125465025791e-65, 5.245487524589388e-65, 2.622743762294515e-64, 1.2898739814563793e-63, 6.241325716724519e-63, 2.9720598651070062e-62, 1.3931530617688636e-61, 6.42993720816397e-61, 2.92269873098366e-60, 1.3086710735747233e-59, 5.773548854006299e-59, 2.510238632176586e-58, 1.075816556647147e-57, 4.545703760480971e-57, 1.8940432335336415e-56, 7.783739315891554e-56, 3.1555699929292893e-55, 1.2622279971716
# your code here
m=35 
#std error is calculated for my sample, stdev taken into account the number of elements in my sample
#8 is the std dev of my population but it should be a diff stdev for my sample
se=8/np.sqrt(200)
cdf_probability = stats.norm.cdf(35, m, se) - stats.norm.cdf(30, m, se)
cdf_probability
# Out:
# 0.5

# %%
m=35 
#std error is calculated for my sample 
stdv=8
cdf_probability = stats.norm.cdf(35, m, stdv) - stats.norm.cdf(30, m, stdv)
cdf_probability
# Out:
# 0.23401447095129946

# %% [markdown]
# #### Step 2: What is the probability that in total, it takes more than 115 hours to deliver all 200 packages?

# %%
# your code here
m=35
se=8/np.sqrt(200)
cdf_probability = 1 - stats.norm.cdf(6900/200,m,se) # 1 - stats as it is from this number
cdf_probability
# Out:
# 0.8116204410942089

# %% [markdown]
# # Challenge 5 - Normal Variables
# The value (in thousands) of the monthly sales of a publishing company follows a normal distribution with a mean equal to 200 and a standard deviation equal to 40.
#
# <div align="center">$X → N(200,40)$</div>
#
# **Hint**: `stats.norm.cdf` can help you find the answers.
#
# #### Step 1: Find the probability that the monthly sales are more than 300.

# %%
# your code here
mean=200
stdev=40

proba_sales = 1 - stats.norm.cdf(300,mean,stdev) 
proba_sales
# Out:
# 0.006209665325776159

# %%
1-stats.norm(200, 40).cdf(300)
# Out:
# 0.006209665325776159

# %% [markdown]
# #### Step 2: Find the probability that the monthly sales fall between 160 and 240.

# %%
# your code here
proba_sales2 = stats.norm.cdf(240, mean, stdev) - stats.norm.cdf(160, mean, stdev)
proba_sales2
# Out:
# 0.6826894921370859

# %% [markdown]
# #### Step 3: Find the probability that the monthly sales do not exceed 150.

# %%
# your code here
proba_sales3 = stats.norm.cdf(150,mean,stdev) 
proba_sales3
# Out:
# 0.10564977366685535

# %% [markdown]
# #### Step 4: Find the probability that the monthly sales exceed 3000.

# %%
# your code here
proba_sales4 = 1 - stats.norm.cdf(3000,mean,stdev) 
proba_sales4
# Out:
# 0.0

# %% [markdown]
# # Challenge 6 - Poisson distribution
# The mean number of violent robberies per month that are registered in a particular barrio is 4.
#
# **Hint**: `stats.poisson.cdf` can help you find the answers.
#
# #### Step 1: Find the probability that in a particular month there is no violent robbery.

# %%
# your code here
meanp=4
stats.poisson.cdf(0, meanp)
# Out:
# 0.018315638888734182

# %% [markdown]
# #### Step 2: Find the probability that there are at least 1 robbery in a given month.

# %%
# your code here
probap2=1- stats.poisson.cdf(0, meanp)
probap2
# Out:
# 0.9816843611112658

# %% [markdown]
# #### Step 3: Find the probability that there are between 2 and 6 (inclusive) robberies in a given month.

# %%
# your code here
probap3 = stats.poisson.cdf(6,meanp) - stats.poisson.cdf(2, meanp)
probap3
# Out:
# 0.6512227160438819

# %% [markdown]
# #### Step 4: Find the probability that there are more than 2 robberies in 15 days.

# %%
# your code here
probap4=1- stats.poisson.cdf(2, meanp/2)
probap4
# Out:
# 0.3233235838169366
