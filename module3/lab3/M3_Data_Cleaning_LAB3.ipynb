# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
iris = pd.read_csv(r'/Users/naitsaidifariza/Desktop/DAFT_257/module_3/Lab_3_Data-Cleaning-Challenge/iris-data.csv')
iris
# Out:
#      sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0                5.1             3.5              1.4             0.2
# 1                4.9             3.0              1.4             0.2
# 2                4.7             3.2              1.3             0.2
# 3                4.6             3.1              1.5             0.2
# 4                5.0             3.6              1.4             0.2
# ..               ...             ...              ...             ...
# 145              6.7             3.0              5.2             2.3
# 146              6.3             2.5              5.0             2.3
# 147              6.5             3.0              5.2             2.0
# 148              6.2             3.4              5.4             2.3
# 149              5.9             3.0              5.1             1.8
#
#               class
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# ...

# %%
iris.dtypes
# Out:
# sepal_length_cm    float64
# sepal_width_cm     float64
# petal_length_cm    float64
# petal_width_cm     float64
# class               object
# dtype: object

# %%
missing_values=iris.index[iris.isnull().any(axis=1)]
missing_values
# Out:
# Int64Index([7, 8, 9, 10, 11], dtype='int64')

# %%
iris.isna().sum()
# Out:
# sepal_length_cm    0
# sepal_width_cm     0
# petal_length_cm    0
# petal_width_cm     5
# class              0
# dtype: int64

# %%
iris.head(15)
# Out:
#     sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0               5.1             3.5              1.4             0.2
# 1               4.9             3.0              1.4             0.2
# 2               4.7             3.2              1.3             0.2
# 3               4.6             3.1              1.5             0.2
# 4               5.0             3.6              1.4             0.2
# 5               5.4             3.9              1.7             0.4
# 6               4.6             3.4              1.4             0.3
# 7               5.0             3.4              1.5             NaN
# 8               4.4             2.9              1.4             NaN
# 9               4.9             3.1              1.5             NaN
# 10              5.4             3.7              1.5             NaN
# 11              4.8             3.4              1.6             NaN
# 12              4.8             3.0              1.4             0.1
# ...

# %%
iris['class'].value_counts()
# Out:
# Iris-virginica     50
# Iris-setosa        49
# Iris-versicolor    45
# versicolor          5
# Iris-setossa        1
# Name: class, dtype: int64

# %%
mean_setosa=np.mean(iris.loc[lambda iris: iris['class'] =='Iris-setosa'])
mean_setosa
# Out:
# /Users/naitsaidifariza/opt/anaconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3438: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# /Users/naitsaidifariza/opt/anaconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3438: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# sepal_length_cm    5.020408
# sepal_width_cm     3.410204
# petal_length_cm    1.459184
# petal_width_cm     0.250000
# dtype: float64

# %%
iris_2= iris.fillna(mean_setosa)

# %%
iris_2.head(15)
# Out:
#     sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0               5.1             3.5              1.4            0.20
# 1               4.9             3.0              1.4            0.20
# 2               4.7             3.2              1.3            0.20
# 3               4.6             3.1              1.5            0.20
# 4               5.0             3.6              1.4            0.20
# 5               5.4             3.9              1.7            0.40
# 6               4.6             3.4              1.4            0.30
# 7               5.0             3.4              1.5            0.25
# 8               4.4             2.9              1.4            0.25
# 9               4.9             3.1              1.5            0.25
# 10              5.4             3.7              1.5            0.25
# 11              4.8             3.4              1.6            0.25
# 12              4.8             3.0              1.4            0.10
# ...

# %%
fig, axs = plt.subplots(2, 2, figsize=(15,10))
axs[0, 0].boxplot(iris_repaired['sepal_length_cm'])
axs[0, 0].set_title('sepal length')

axs[0, 1].boxplot(iris_repaired['sepal_width_cm'])
axs[0, 1].set_title('sepal width')

axs[1, 0].boxplot(iris_repaired['petal_length_cm'])
axs[1, 0].set_title('petal length')

axs[1, 1].boxplot(iris_repaired['petal_width_cm'])
axs[1, 1].set_title('petal width')
# Out:
# Text(0.5, 1.0, 'petal width')

# %%
iris_2.drop_duplicates(keep=('first'), inplace = True)

# %%
stats = iris_2.describe().transpose()
stats['IQR'] = stats['75%'] - stats['25%']
stats
# Out:
#                  count      mean       std    min  25%   50%  75%  max  IQR
# sepal_length_cm  148.0  5.648608  1.320186  0.055  5.1  5.70  6.4  7.9  1.3
# sepal_width_cm   148.0  3.056757  0.435056  2.000  2.8  3.00  3.3  4.4  0.5
# petal_length_cm  148.0  3.764865  1.763109  1.000  1.6  4.35  5.1  6.9  3.5
# petal_width_cm   148.0  1.206419  0.760846  0.100  0.3  1.30  1.8  2.5  1.5

# %%
outliers = pd.DataFrame(columns=iris_2.columns)
 
for col in stats.index:
    iqr = stats.at[col,'IQR']
    cutoff = iqr * 1.5
    lower = stats.at[col,'25%'] - cutoff
    upper = stats.at[col,'75%'] + cutoff
    results = iris_2[(iris_2[col] < lower) | 
                   (iris_2[col] > upper)].copy()
    results['Outlier'] = col
    outliers = outliers.append(results)
outliers
# Out:
# /var/folders/rd/z1bdcjpx79n0y16wywgzmh700000gn/T/ipykernel_56929/514709817.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   outliers = outliers.append(results)
# /var/folders/rd/z1bdcjpx79n0y16wywgzmh700000gn/T/ipykernel_56929/514709817.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   outliers = outliers.append(results)
# /var/folders/rd/z1bdcjpx79n0y16wywgzmh700000gn/T/ipykernel_56929/514709817.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   outliers = outliers.append(results)
# /var/folders/rd/z1bdcjpx79n0y16wywgzmh700000gn/T/ipykernel_56929/514709817.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
outliers.value_counts().sum()
# Out:
# 9

# %%
index_to_drop=outliers.index
index_to_drop
# Out:
# Int64Index([77, 78, 79, 80, 81, 15, 32, 33, 60], dtype='int64')

# %%
iris_2=iris_2.drop(index=index_to_drop)

# %%
iris_2
# Out:
#      sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0                5.1             3.5              1.4             0.2
# 1                4.9             3.0              1.4             0.2
# 2                4.7             3.2              1.3             0.2
# 3                4.6             3.1              1.5             0.2
# 4                5.0             3.6              1.4             0.2
# ..               ...             ...              ...             ...
# 145              6.7             3.0              5.2             2.3
# 146              6.3             2.5              5.0             2.3
# 147              6.5             3.0              5.2             2.0
# 148              6.2             3.4              5.4             2.3
# 149              5.9             3.0              5.1             1.8
#
#               class
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# ...

# %%
print(len(iris_2)/len(iris)*100, '%')
# Out:
# 92.66666666666666 %

# %%
iris_2.to_csv(r'/Users/naitsaidifariza/iris_2.csv')
